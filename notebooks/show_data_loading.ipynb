# %%
import datetime as dt
import definitions as d
from utils.data_loading import load_downloaded_data, download_new_subreddit_and_preprocess

# %% [markdown]
# # 1. Load data for a specific period of time that is already downloaded
# Firstly tries to load from `data\cache`.
# Then from `data\preprocesed`.
# And finally from `data\raw`.

# %%
input_data_1 = load_downloaded_data(subreddits=['askmen'], date_range=[dt.date(2022, 9, 1), dt.date(2022, 9, 10)])

# %%
input_data_1.texts
# Out:
# [['deal',
#   'wanting',
#   'baby',
#   'gf',
#   'ready',
#   'ha',
#   'leading',
#   'tell',
#   'hesitant',
#   'time',
#   'let',
#   'finish',
#   'inside'],
#  ['use', 'fly', 'underwear', 'pee'],
#  ['men', 'post', 'partner', 'social', 'medium', 'title', 'say', 'all~'],
#  ['know', 'love'],
#  ['guy', 'feel', 'girl', 'acting', 'hard', 'get'],
#  ['pet', 'name', 'choose'],
#  ['common',
#   'men',
#   'take',
#   'shirt',
#   'going',
#   'remembered',
#   'guy',
#   'friend',
#   'mine',
#   'say',
#   'doe',
#   'whenever',
#   'go',
#   'bathroom',
#   'normal',
#   'weird'],
#  ['something', 'wish', 'girlfriend', 'understood'],
#  ['something', 'would', 'never', 'tell', 'girlfriend'],
#  ['guy',
#   'girl',
#   'told',
#   'never',
#   'let',
#   'someone',
#   'record',
#   'say',
#   'first',
#   'said',
#   'saw',
#   'old',
#   'message',
#   'together',
#   'saying',
#   'show',
#   'anyone',
#   'recently',
#   'someone',
#   'ha',
#   'harassing',
#   'recording',
# ...

# %%
input_data_1.df
# Out:
#                                              lematized        date
# 0    [deal, wanting, baby, gf, ready, ha, leading, ...  2022-09-01
# 1                           [use, fly, underwear, pee]  2022-09-01
# 2    [men, post, partner, social, medium, title, sa...  2022-09-01
# 3                                         [know, love]  2022-09-01
# 4                 [guy, feel, girl, acting, hard, get]  2022-09-01
# ..                                                 ...         ...
# 489  [something, socially, acceptable, make, ask, '...  2022-09-10
# 490  [making, hour, drive, mountain, tomorrow, podc...  2022-09-10
# 491  [female, retreat, sit, around, campfire, paint...  2022-09-10
# 492  [long, doe, take, get, comfortable, new, partner]  2022-09-10
# 493                 [men, waited, marriage, wa, worth]  2022-09-10
#
# [494 rows x 2 columns]

# %% [markdown]
# # 2. Download data that is missing

# %%
download_new_subreddit_and_preprocess('recipes', date_range=[d.START_DATE, d.END_DATE])
# Out:
# day 0:
#
# processed 18 entries
# day 1:
#
# processed 33 entries
# day 2:
#
# processed 43 entries
# day 3:
#
# processed 68 entries
# day 4:
#
# processed 80 entries
# day 5:
#
# processed 100 entries
# day 6:
#
# processed 115 entries
# day 7:
#
# processed 130 entries
# day 8:
#
# processed 148 entries
# day 9:
#
# processed 165 entries
# day 10:
#
# processed 182 entries
# day 11:
#
# processed 198 entries
# day 12:
#
# processed 212 entries
# day 13:
#
# processed 233 entries
# day 14:
#
# processed 249 entries
# day 15:
#
# processed 268 entries
# day 16:
#
# processed 285 entries
# day 17:
#
# processed 303 entries
# day 18:
#
# processed 315 entries
# day 19:
#
# processed 345 entries
# day 20:
#
# processed 357 entries
# day 21:
#
# processed 381 entries
# day 22:
#
# processed 400 entries
# day 23:
#
# processed 413 entries
# day 24:
#
# processed 429 entries
# day 25:
#
# processed 442 entries
# day 26:
#
# processed 456 entries
# day 27:
#
# processed 474 entries
# ...
